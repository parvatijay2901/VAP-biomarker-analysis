# %% [markdown]
# # Some stats
#
# ## 1. Import necessary libraries, have function definitions

# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import mannwhitneyu, kruskal, fisher_exact, chi2_contingency
from statsmodels.miscmodels.ordinal_model import OrderedModel

from pprint import pprint

import warnings
warnings.filterwarnings("ignore")

# %%
# Fit a logistic regression model with robust standard errors
def run_logistic_regression(data, formula):
    model = smf.glm(formula=formula, 
                    data=data, 
                    family=sm.families.Binomial()).fit(cov_type='HC0')  # HC0 = Robust SEs
    
    print(model.summary())

    # Compute Odds Ratios (exponentiate the coefficients)
    odds_ratios = np.exp(model.params)
    
    print("\nOdds Ratios:")
    print(odds_ratios)
    
    return model

# %%
# Define vfds groups
def categorize_vfds_bronch(x):
    if 0 <= x <= 7:
        return 1
    elif 8 <= x <= 14:
        return 2
    elif 15 <= x <= 21:
        return 3
    elif 22 <= x <= 28:
        return 4
    else:
        return None

# %%
# Fit a modified Poisson regression model with Huber-White robust standard error.
def run_modified_poisson_regression(data, formula):
    
    # Fit the model
    model = smf.glm(formula=formula, 
                    data=data, 
                    family=sm.families.Poisson()).fit(cov_type='HC0')
    print(model.summary())
    
    # Calculate relative risks by exponentiating the coefficients
    relative_risks = np.exp(model.params)

    print("\nRelative Risks (exponentiated coefficients):")
    print(relative_risks)

# %%
# Create a summary table for selected variables, stratified by a grouping variable.
def create_summary_table(df, group_var='cluster'):

    continuous_vars = ['BMI', 'Age', 'bronch_day_1', 'sofa_icu', 'sofa_b1']
    categorical_vars = ['Sex', 'Race', 'Ethnicity', 'mortality_28d', 'hospital_mortality', 'icu_mortality']
    
    summary = {'continuous': {}, 'categorical': {}}
    
    # Determine groups
    groups = sorted(df[group_var].dropna().unique())
    n_groups = len(groups)
    
    # 1. Continuous variables
    for var in continuous_vars:
        # Overall median, IQR
        overall_median = df[var].median()
        overall_iqr = (df[var].quantile(0.25), df[var].quantile(0.75))
        
        # Group-specific median, IQR
        group_summary = {}
        group_series = []
        for g in groups:
            grp_vals = df.loc[df[group_var] == g, var].dropna()
            group_series.append(grp_vals)
            
            if len(grp_vals) > 0:
                g_median = grp_vals.median()
                g_iqr = (grp_vals.quantile(0.25), grp_vals.quantile(0.75))
                group_summary[g] = f"{g_median:.1f} ({g_iqr[0]:.1f} to {g_iqr[1]:.1f})"
            else:
                group_summary[g] = "NA (NA to NA)"
        
        # p-value: Mann-Whitney if 2 groups, Kruskal-Wallis if >2
        if n_groups == 2:
            try:
                stat, pval = mannwhitneyu(group_series[0], group_series[1], alternative='two-sided')
            except:
                pval = np.nan
        else:
            try:
                stat, pval = kruskal(*group_series)
            except:
                pval = np.nan
        
        summary['continuous'][var] = {
            'Overall': f"{overall_median:.1f} ({overall_iqr[0]:.1f} to {overall_iqr[1]:.1f})",
            'By Group': group_summary,
            'p-value': pval
        }

    # 2. Categorical variables
    for var in categorical_vars:
        summary['categorical'][var] = {'By Category': {}}
        
        # Identify all categories
        categories = df[var].dropna().unique()
        
        for cat in categories:
            row_dict = {}
            # Overall count/percent for this category
            is_cat = (df[var] == cat)
            cat_count = is_cat.sum()
            total_count = df[var].notna().sum()
            cat_percent = 100.0 * cat_count / total_count if total_count else 0
            row_dict["Overall"] = f"{cat_count} ({cat_percent:.1f}%)"
            
            # Group-specific counts/percents
            cat_counts = []
            not_cat_counts = []
            for g in groups:
                grp_df = df[df[group_var] == g]
                grp_cat_count = (grp_df[var] == cat).sum()
                grp_total = grp_df[var].notna().sum()
                grp_percent = 100.0 * grp_cat_count / grp_total if grp_total else 0
                row_dict[g] = f"{grp_cat_count} ({grp_percent:.1f}%)"
                
                # For building the 2-row x n-groups table
                cat_counts.append(grp_cat_count)
                not_cat_counts.append(grp_total - grp_cat_count)
            
            # p-value for "this category vs. not this category" across the groups
            contingency = np.array([cat_counts, not_cat_counts])
            if n_groups == 2:
                # Fisher's exact for 2 groups
                try:
                    _, p_val = fisher_exact(contingency)
                except:
                    p_val = np.nan
            else:
                # Chi-square for >2 groups
                try:
                    _, p_val, _, _ = chi2_contingency(contingency)
                except:
                    p_val = np.nan
            
            row_dict["p-value"] = p_val
            
            summary['categorical'][var]['By Category'][cat] = row_dict
    
    return summary

# %% [markdown]
# ## 2. Load the data
#
# First, load the raw data

# %%
file_path = "../data/raw_data/Daily_merged_2025-02-27(in).csv"
sheet_name = "in"

# read the raw data
df_raw = pd.read_csv(file_path)
df_raw = df_raw[df_raw["cohort"] == "vap"]
df_raw = df_raw[df_raw["repeat"] == 1]
df_raw = df_raw.dropna(subset=['balf_PD-L1_V1_imputed'])
df_raw = df_raw.reset_index(drop=True)
print(df_raw.shape)
df_raw.head()
# Out:
# (466, 2677)
#                                            merged_id subject_id cohort  \
# 0  0060cb7f038fc2524edc6c5fd51c1311f7dab5fd460126...       3901    vap
# 1  010a9d89899aff76eca797c6b0b88baa321a7c465cc5aa...       3695    vap
# 2  0138d106c8ad7c0ae0712e4ea5a8b9d5d1c4410d2db4bc...       4097    vap
# 3  0196c36dc652445d5d25d38bcbee46b0e2e40d91884fa9...       3738    vap
# 4  01cc89f062a95ba91cd58800437cb2ef29b48b867701b6...       3791    vap
#
#    repeat                                         encoded_id  \
# 0       1  bdcedd0872be7c0678cfe00884f0ef3b7f833e00937b48...
# 1       1  c1738fe9ecd511185d729136745c384958e6e009e47080...
# 2       1  ab1b10eb5052132cfa1465402af4d3af7fd4f008c1084a...
# 3       1  6f5dff78f3c7c63081fcbced005868465e7f1d9aa1f640...
# 4       1  09b4890ada6e16740d1a18a7ba5578e02efcb5d1821d89...
#
#                  true_admit_date              admit_date_redcap  \
# 0  2021-02-01T00:00:00.000000000  2021-02-01T00:00:00.000000000
# 1  2018-07-02T00:00:00.000000000  2018-07-02T00:00:00.000000000
# 2  2023-08-06T00:00:00.000000000  2023-08-06T00:00:00.000000000
# 3  2019-06-22T00:00:00.000000000  2019-06-22T00:00:00.000000000
# 4  2020-02-09T00:00:00.000000000  2020-02-09T00:00:00.000000000
#
#              icu_admit_date_iths           icu_admit_source icu_admit_type  \
# 0  2021-02-01T21:39:00.000000000       Emergency department       Surgical
# 1  2018-07-03T23:50:00.000000000       Emergency department          Neuro
# 2  2023-08-06T04:48:00.000000000       Emergency department       Surgical
# 3  2019-07-01T23:52:00.000000000  Outside hospital transfer       Surgical
# 4  2020-02-08T18:06:00.000000000       Emergency department          Neuro
#
#    ... pc_IL-10_proinf_V1_imputed pc_IL-12p70_proinf_V1_imputed  \
# 0  ...                        NaN                           NaN
# 1  ...                        NaN                           NaN
# 2  ...                        NaN                           NaN
# 3  ...                        NaN                           NaN
# 4  ...                        NaN                           NaN
#
#    pc_IL-13_proinf_V1_imputed pc_IL-1?_proinf_V1_imputed  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   pc_IL-2_proinf_V1_imputed pc_IL-4_proinf_V1_imputed  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   pc_IL-6_proinf_V1_imputed pc_TNF-?_proinf_V1_imputed pc_sRAGE_V1_imputed  \
# 0                       NaN                        NaN                 NaN
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
#
#   pc_TNF-RI_V1_imputed
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 2677 columns]

# %% [markdown]
# Then, let us load the biomarker data that also has the clusters

# %%
# Biomarker data with clusters
file_path = "../data/clean_data/vap_cluster_assignments_k4_ted.csv"
df_biomarker = pd.read_csv(file_path)
df_biomarker.head()
# Out:
#    Unnamed: 0  subject_id  cluster
# 0           1        3901        3
# 1           2        3695        4
# 2           3        4097        4
# 3           4        3738        3
# 4           5        3791        4

# %%
# # Biomarker data (after removing not correlated variables) with clusters
# file_path = "../data/clean_data/scaled_biomarker_data_notcorrelated_with_clusters.csv"
# df_biomarker_notcorrelated = pd.read_csv(file_path)
# df_biomarker_notcorrelated.head()

# %%
table1_columns = ['subject_id', 'BMI', 'Age', 'bronch_day_1', 'sofa_icu', 'sofa_b1', 'Sex', 'Race', 
               'Ethnicity', '28d_mortality', 'hospital_mortality', 'icu_mortality']
table1_df_correlated = df_raw[table1_columns]
table1_df_correlated = pd.merge(df_raw[table1_columns], df_biomarker, on='subject_id', how='inner')
table1_df_correlated.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)
table1_df_correlated.drop(columns=["Unnamed: 0"], inplace=True)

# %% [markdown]
# ## 3. Participant Characteristics

# %%
summary_table = create_summary_table(table1_df_correlated)
pprint(summary_table)
# Out:
# {'categorical': {'Ethnicity': {'By Category': {'Hispanic or Latino': {np.int64(1): '0 '
#                                                                                    '(0.0%)',
#                                                                       np.int64(2): '1 '
#                                                                                    '(2.3%)',
#                                                                       np.int64(3): '0 '
#                                                                                    '(0.0%)',
#                                                                       np.int64(4): '0 '
#                                                                                    '(0.0%)',
#                                                                       'Overall': '1 '
#                                                                                  '(0.3%)',
#                                                                       'p-value': np.float64(0.06984179548317501)},
#                                                'Hispanic or Latino/a or Latinx': {np.int64(1): '11 '
#                                                                                                '(8.7%)',
#                                                                                   np.int64(2): '5 '
#                                                                                                '(11.4%)',
#                                                                                   np.int64(3): '11 '
#                                                                                                '(11.8%)',
#                                                                                   np.int64(4): '6 '
#                                                                                                '(6.6%)',
#                                                                                   'Overall': '33 '
#                                                                                              '(9.3%)',
#                                                                                   'p-value': np.float64(0.6233288018943066)},
#                                                'NOT Hispanic or Latino': {np.int64(1): '3 '
#                                                                                        '(2.4%)',
#                                                                           np.int64(2): '0 '
#                                                                                        '(0.0%)',
#                                                                           np.int64(3): '1 '
#                                                                                        '(1.1%)',
#                                                                           np.int64(4): '1 '
#                                                                                        '(1.1%)',
#                                                                           'Overall': '5 '
#                                                                                      '(1.4%)',
#                                                                           'p-value': np.float64(0.6550155335237595)},
#                                                'Non-Hispanic or Latino/a or Latinx': {np.int64(1): '108 '
#                                                                                                    '(85.7%)',
#                                                                                       np.int64(2): '37 '
#                                                                                                    '(84.1%)',
#                                                                                       np.int64(3): '79 '
#                                                                                                    '(84.9%)',
#                                                                                       np.int64(4): '80 '
#                                                                                                    '(87.9%)',
#                                                                                       'Overall': '304 '
#                                                                                                  '(85.9%)',
#                                                                                       'p-value': np.float64(0.9198529202569655)},
#                                                'Patient declined to respond': {np.int64(1): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(2): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(3): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(4): '1 '
#                                                                                             '(1.1%)',
#                                                                                'Overall': '1 '
#                                                                                           '(0.3%)',
#                                                                                'p-value': np.float64(0.4075730073928233)},
#                                                'Unknown to patient': {np.int64(1): '4 '
#                                                                                    '(3.2%)',
#                                                                       np.int64(2): '1 '
#                                                                                    '(2.3%)',
#                                                                       np.int64(3): '2 '
#                                                                                    '(2.2%)',
#                                                                       np.int64(4): '3 '
#                                                                                    '(3.3%)',
#                                                                       'Overall': '10 '
#                                                                                  '(2.8%)',
#                                                                       'p-value': np.float64(0.9537332494850814)}}},
#                  'Race': {'By Category': {'Alaska Native': {np.int64(1): '1 '
#                                                                          '(0.8%)',
#                                                             np.int64(2): '0 '
#                                                                          '(0.0%)',
#                                                             np.int64(3): '0 '
#                                                                          '(0.0%)',
#                                                             np.int64(4): '0 '
#                                                                          '(0.0%)',
#                                                             'Overall': '1 '
#                                                                        '(0.3%)',
#                                                             'p-value': np.float64(0.6117521457896249)},
#                                           'American Indian or Native Alaskan': {np.int64(1): '4 '
#                                                                                              '(3.2%)',
#                                                                                 np.int64(2): '2 '
#                                                                                              '(4.5%)',
#                                                                                 np.int64(3): '1 '
#                                                                                              '(1.1%)',
#                                                                                 np.int64(4): '2 '
#                                                                                              '(2.2%)',
#                                                                                 'Overall': '9 '
#                                                                                            '(2.5%)',
#                                                                                 'p-value': np.float64(0.6220822259010284)},
#                                           'American Indian or Native Alaskan,Black or African-American': {np.int64(1): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           np.int64(2): '1 '
#                                                                                                                        '(2.3%)',
#                                                                                                           np.int64(3): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           np.int64(4): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           'Overall': '1 '
#                                                                                                                      '(0.3%)',
#                                                                                                           'p-value': np.float64(0.06984179548317501)},
#                                           'American Indian or Native Alaskan,White': {np.int64(1): '1 '
#                                                                                                    '(0.8%)',
#                                                                                       np.int64(2): '0 '
#                                                                                                    '(0.0%)',
#                                                                                       np.int64(3): '0 '
#                                                                                                    '(0.0%)',
#                                                                                       np.int64(4): '1 '
#                                                                                                    '(1.1%)',
#                                                                                       'Overall': '2 '
#                                                                                                  '(0.6%)',
#                                                                                       'p-value': np.float64(0.7155297304898252)},
#                                           'Another Race': {np.int64(1): '0 '
#                                                                         '(0.0%)',
#                                                            np.int64(2): '1 '
#                                                                         '(2.3%)',
#                                                            np.int64(3): '0 '
#                                                                         '(0.0%)',
#                                                            np.int64(4): '0 '
#                                                                         '(0.0%)',
#                                                            'Overall': '1 '
#                                                                       '(0.3%)',
#                                                            'p-value': np.float64(0.06984179548317501)},
#                                           'Asian': {np.int64(1): '7 (5.6%)',
#                                                     np.int64(2): '5 (11.4%)',
#                                                     np.int64(3): '6 (6.5%)',
#                                                     np.int64(4): '3 (3.3%)',
#                                                     'Overall': '21 (5.9%)',
#                                                     'p-value': np.float64(0.3161534703606417)},
#                                           'Asian,Native Hawaiian or Pacific Islander': {np.int64(1): '1 '
#                                                                                                      '(0.8%)',
#                                                                                         np.int64(2): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         np.int64(3): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         np.int64(4): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         'Overall': '1 '
#                                                                                                    '(0.3%)',
#                                                                                         'p-value': np.float64(0.6117521457896249)},
#                                           'Asian,Pacific Islander': {np.int64(1): '0 '
#                                                                                   '(0.0%)',
#                                                                      np.int64(2): '1 '
#                                                                                   '(2.3%)',
#                                                                      np.int64(3): '0 '
#                                                                                   '(0.0%)',
#                                                                      np.int64(4): '0 '
#                                                                                   '(0.0%)',
#                                                                      'Overall': '1 '
#                                                                                 '(0.3%)',
#                                                                      'p-value': np.float64(0.06984179548317501)},
#                                           'Black or African American': {np.int64(1): '1 '
#                                                                                      '(0.8%)',
#                                                                         np.int64(2): '0 '
#                                                                                      '(0.0%)',
#                                                                         np.int64(3): '1 '
#                                                                                      '(1.1%)',
#                                                                         np.int64(4): '1 '
#                                                                                      '(1.1%)',
#                                                                         'Overall': '3 '
#                                                                                    '(0.8%)',
#                                                                         'p-value': np.float64(0.9175009164150123)},
#                                           'Black or African-American': {np.int64(1): '14 '
#                                                                                      '(11.1%)',
#                                                                         np.int64(2): '4 '
#                                                                                      '(9.1%)',
#                                                                         np.int64(3): '10 '
#                                                                                      '(10.8%)',
#                                                                         np.int64(4): '9 '
#                                                                                      '(9.9%)',
#                                                                         'Overall': '37 '
#                                                                                    '(10.5%)',
#                                                                         'p-value': np.float64(0.9799338384742996)},
#                                           'Black or African-American,Asian,White': {np.int64(1): '0 '
#                                                                                                  '(0.0%)',
#                                                                                     np.int64(2): '1 '
#                                                                                                  '(2.3%)',
#                                                                                     np.int64(3): '0 '
#                                                                                                  '(0.0%)',
#                                                                                     np.int64(4): '0 '
#                                                                                                  '(0.0%)',
#                                                                                     'Overall': '1 '
#                                                                                                '(0.3%)',
#                                                                                     'p-value': np.float64(0.06984179548317501)},
#                                           'Black or African-American,Unavailable or Unknown': {np.int64(1): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                np.int64(2): '1 '
#                                                                                                             '(2.3%)',
#                                                                                                np.int64(3): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                np.int64(4): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                'Overall': '1 '
#                                                                                                           '(0.3%)',
#                                                                                                'p-value': np.float64(0.06984179548317501)},
#                                           'Black or African-American,White': {np.int64(1): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(2): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(3): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(4): '1 '
#                                                                                            '(1.1%)',
#                                                                               'Overall': '1 '
#                                                                                          '(0.3%)',
#                                                                               'p-value': np.float64(0.4075730073928233)},
#                                           'Declined to Answer': {np.int64(1): '0 '
#                                                                               '(0.0%)',
#                                                                  np.int64(2): '0 '
#                                                                               '(0.0%)',
#                                                                  np.int64(3): '2 '
#                                                                               '(2.2%)',
#                                                                  np.int64(4): '0 '
#                                                                               '(0.0%)',
#                                                                  'Overall': '2 '
#                                                                             '(0.6%)',
#                                                                  'p-value': np.float64(0.13023026569234414)},
#                                           'Declined to Answer,Black or African-American': {np.int64(1): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            np.int64(2): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            np.int64(3): '1 '
#                                                                                                         '(1.1%)',
#                                                                                            np.int64(4): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            'Overall': '1 '
#                                                                                                       '(0.3%)',
#                                                                                            'p-value': np.float64(0.42113459195521374)},
#                                           'Declined to Answer,White': {np.int64(1): '0 '
#                                                                                     '(0.0%)',
#                                                                        np.int64(2): '0 '
#                                                                                     '(0.0%)',
#                                                                        np.int64(3): '1 '
#                                                                                     '(1.1%)',
#                                                                        np.int64(4): '0 '
#                                                                                     '(0.0%)',
#                                                                        'Overall': '1 '
#                                                                                   '(0.3%)',
#                                                                        'p-value': np.float64(0.42113459195521374)},
#                                           'Native Hawaiian or Pacific Islander': {np.int64(1): '4 '
#                                                                                                '(3.2%)',
#                                                                                   np.int64(2): '0 '
#                                                                                                '(0.0%)',
#                                                                                   np.int64(3): '1 '
#                                                                                                '(1.1%)',
#                                                                                   np.int64(4): '1 '
#                                                                                                '(1.1%)',
#                                                                                   'Overall': '6 '
#                                                                                              '(1.7%)',
#                                                                                   'p-value': np.float64(0.4197823456537011)},
#                                           'Unavailable or Unknown': {np.int64(1): '5 '
#                                                                                   '(4.0%)',
#                                                                      np.int64(2): '0 '
#                                                                                   '(0.0%)',
#                                                                      np.int64(3): '1 '
#                                                                                   '(1.1%)',
#                                                                      np.int64(4): '1 '
#                                                                                   '(1.1%)',
#                                                                      'Overall': '7 '
#                                                                                 '(2.0%)',
#                                                                      'p-value': np.float64(0.23897455917985228)},
#                                           'Unavailable or Unknown,American Indian or Native Alaskan,White': {np.int64(1): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(2): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(3): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(4): '1 '
#                                                                                                                           '(1.1%)',
#                                                                                                              'Overall': '1 '
#                                                                                                                         '(0.3%)',
#                                                                                                              'p-value': np.float64(0.4075730073928233)},
#                                           'Unavailable or Unknown,Unable to Collect': {np.int64(1): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        np.int64(2): '1 '
#                                                                                                     '(2.3%)',
#                                                                                        np.int64(3): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        np.int64(4): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        'Overall': '1 '
#                                                                                                   '(0.3%)',
#                                                                                        'p-value': np.float64(0.06984179548317501)},
#                                           'Unavailable or Unknown,White': {np.int64(1): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(2): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(3): '1 '
#                                                                                         '(1.1%)',
#                                                                            np.int64(4): '0 '
#                                                                                         '(0.0%)',
#                                                                            'Overall': '1 '
#                                                                                       '(0.3%)',
#                                                                            'p-value': np.float64(0.42113459195521374)},
#                                           'White': {np.int64(1): '87 (69.0%)',
#                                                     np.int64(2): '26 (59.1%)',
#                                                     np.int64(3): '67 (72.0%)',
#                                                     np.int64(4): '69 (75.8%)',
#                                                     'Overall': '249 (70.3%)',
#                                                     'p-value': np.float64(0.23958970114750927)},
#                                           'White,Asian': {np.int64(1): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(2): '1 '
#                                                                        '(2.3%)',
#                                                           np.int64(3): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(4): '0 '
#                                                                        '(0.0%)',
#                                                           'Overall': '1 (0.3%)',
#                                                           'p-value': np.float64(0.06984179548317501)},
#                                           'White,Black or African-American': {np.int64(1): '1 '
#                                                                                            '(0.8%)',
#                                                                               np.int64(2): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(3): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(4): '1 '
#                                                                                            '(1.1%)',
#                                                                               'Overall': '2 '
#                                                                                          '(0.6%)',
#                                                                               'p-value': np.float64(0.7155297304898252)},
#                                           'White,Unavailable or Unknown': {np.int64(1): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(2): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(3): '1 '
#                                                                                         '(1.1%)',
#                                                                            np.int64(4): '1 '
#                                                                                         '(1.1%)',
#                                                                            'Overall': '2 '
#                                                                                       '(0.6%)',
#                                                                            'p-value': np.float64(0.6022275299626763)}}},
#                  'Sex': {'By Category': {'Female': {np.int64(1): '33 (26.2%)',
#                                                     np.int64(2): '15 (34.1%)',
#                                                     np.int64(3): '23 (24.7%)',
#                                                     np.int64(4): '22 (24.2%)',
#                                                     'Overall': '93 (26.3%)',
#                                                     'p-value': np.float64(0.6347974469268152)},
#                                          'Male': {np.int64(1): '93 (73.8%)',
#                                                   np.int64(2): '29 (65.9%)',
#                                                   np.int64(3): '70 (75.3%)',
#                                                   np.int64(4): '69 (75.8%)',
#                                                   'Overall': '261 (73.7%)',
#                                                   'p-value': np.float64(0.6347974469268152)}}},
#                  'hospital_mortality': {'By Category': {np.int64(0): {np.int64(1): '107 '
#                                                                                    '(84.9%)',
#                                                                       np.int64(2): '41 '
#                                                                                    '(93.2%)',
#                                                                       np.int64(3): '72 '
#                                                                                    '(77.4%)',
#                                                                       np.int64(4): '68 '
#                                                                                    '(74.7%)',
#                                                                       'Overall': '288 '
#                                                                                  '(81.4%)',
#                                                                       'p-value': np.float64(0.03355310637562857)},
#                                                         np.int64(1): {np.int64(1): '19 '
#                                                                                    '(15.1%)',
#                                                                       np.int64(2): '3 '
#                                                                                    '(6.8%)',
#                                                                       np.int64(3): '21 '
#                                                                                    '(22.6%)',
#                                                                       np.int64(4): '23 '
#                                                                                    '(25.3%)',
#                                                                       'Overall': '66 '
#                                                                                  '(18.6%)',
#                                                                       'p-value': np.float64(0.03355310637562857)}}},
#                  'icu_mortality': {'By Category': {np.int64(0): {np.int64(1): '110 '
#                                                                               '(87.3%)',
#                                                                  np.int64(2): '42 '
#                                                                               '(95.5%)',
#                                                                  np.int64(3): '82 '
#                                                                               '(88.2%)',
#                                                                  np.int64(4): '76 '
#                                                                               '(83.5%)',
#                                                                  'Overall': '310 '
#                                                                             '(87.6%)',
#                                                                  'p-value': np.float64(0.26955986512227953)},
#                                                    np.int64(1): {np.int64(1): '16 '
#                                                                               '(12.7%)',
#                                                                  np.int64(2): '2 '
#                                                                               '(4.5%)',
#                                                                  np.int64(3): '11 '
#                                                                               '(11.8%)',
#                                                                  np.int64(4): '15 '
#                                                                               '(16.5%)',
#                                                                  'Overall': '44 '
#                                                                             '(12.4%)',
#                                                                  'p-value': np.float64(0.26955986512227953)}}},
#                  'mortality_28d': {'By Category': {np.int64(0): {np.int64(1): '113 '
#                                                                               '(89.7%)',
#                                                                  np.int64(2): '42 '
#                                                                               '(95.5%)',
#                                                                  np.int64(3): '78 '
#                                                                               '(83.9%)',
#                                                                  np.int64(4): '73 '
#                                                                               '(80.2%)',
#                                                                  'Overall': '306 '
#                                                                             '(86.4%)',
#                                                                  'p-value': np.float64(0.05243575819480186)},
#                                                    np.int64(1): {np.int64(1): '13 '
#                                                                               '(10.3%)',
#                                                                  np.int64(2): '2 '
#                                                                               '(4.5%)',
#                                                                  np.int64(3): '15 '
#                                                                               '(16.1%)',
#                                                                  np.int64(4): '18 '
#                                                                               '(19.8%)',
#                                                                  'Overall': '48 '
#                                                                             '(13.6%)',
#                                                                  'p-value': np.float64(0.05243575819480186)}}}},
#  'continuous': {'Age': {'By Group': {np.int64(1): '55.5 (38.6 to 64.4)',
#                                      np.int64(2): '37.6 (28.1 to 52.1)',
#                                      np.int64(3): '53.1 (38.3 to 64.3)',
#                                      np.int64(4): '46.9 (33.7 to 60.8)'},
#                         'Overall': '51.3 (35.6 to 63.4)',
#                         'p-value': np.float64(0.004252865284644754)},
#                 'BMI': {'By Group': {np.int64(1): '28.2 (24.2 to 34.6)',
#                                      np.int64(2): '26.3 (23.7 to 28.7)',
#                                      np.int64(3): '28.0 (23.9 to 32.5)',
#                                      np.int64(4): '26.6 (24.9 to 31.1)'},
#                         'Overall': '27.4 (24.1 to 32.1)',
#                         'p-value': np.float64(0.22057465179201088)},
#                 'bronch_day_1': {'By Group': {np.int64(1): '6.0 (4.0 to 12.0)',
#                                               np.int64(2): '5.0 (3.0 to 7.0)',
#                                               np.int64(3): '9.0 (5.0 to 16.0)',
#                                               np.int64(4): '7.0 (4.0 to 11.0)'},
#                                  'Overall': '7.0 (4.0 to 12.0)',
#                                  'p-value': np.float64(0.0011821107626197546)},
#                 'sofa_b1': {'By Group': {np.int64(1): '6.0 (4.0 to 7.8)',
#                                          np.int64(2): '7.0 (5.0 to 9.0)',
#                                          np.int64(3): '5.0 (3.0 to 7.0)',
#                                          np.int64(4): '6.0 (4.0 to 8.0)'},
#                             'Overall': '6.0 (4.0 to 8.0)',
#                             'p-value': np.float64(0.011494283018848014)},
#                 'sofa_icu': {'By Group': {np.int64(1): '6.0 (3.0 to 8.0)',
#                                           np.int64(2): '7.0 (4.0 to 10.0)',
#                                           np.int64(3): '6.0 (3.0 to 9.0)',
#                                           np.int64(4): '7.0 (3.5 to 9.0)'},
#                              'Overall': '6.0 (3.0 to 9.0)',
#                              'p-value': np.float64(0.5327391521674998)}}}

# %%
# summary_table = create_summary_table(table1_df_notcorrelated)
# pprint(summary_table)

# %% [markdown]
# ## 4. Relative Risk

# %%
RR_columns = ["subject_id", "Age", "Sex", "28d_mortality", "hospital_mortality"]
RR_df = pd.merge(df_raw[RR_columns], df_biomarker, on='subject_id', how='inner')
RR_df.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)
RR_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
run_modified_poisson_regression(data=RR_df, formula='hospital_mortality ~ cluster + Sex + Age')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  354
# Model:                            GLM   Df Residuals:                      350
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -164.63
# Date:                Fri, 07 Mar 2025   Deviance:                       197.25
# Time:                        06:46:00   Pearson chi2:                     272.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.06677
# Covariance Type:                  HC0
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -3.6909      0.525     -7.035      0.000      -4.719      -2.663
# Sex[T.Male]    -0.3811      0.227     -1.676      0.094      -0.827       0.065
# cluster         0.2221      0.093      2.390      0.017       0.040       0.404
# Age             0.0314      0.007      4.623      0.000       0.018       0.045
# ===============================================================================
#
# Relative Risks (exponentiated coefficients):
# Intercept      0.024950
# Sex[T.Male]    0.683081
# cluster        1.248677
# Age            1.031944
# dtype: float64

# %%
run_modified_poisson_regression(data=RR_df, formula='mortality_28d ~ cluster + Sex + Age')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          mortality_28d   No. Observations:                  354
# Model:                            GLM   Df Residuals:                      350
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -131.51
# Date:                Fri, 07 Mar 2025   Deviance:                       167.02
# Time:                        06:46:04   Pearson chi2:                     303.
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.06764
# Covariance Type:                  HC0
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -4.8378      0.710     -6.818      0.000      -6.229      -3.447
# Sex[T.Male]    -0.1019      0.292     -0.349      0.727      -0.674       0.470
# cluster         0.2657      0.114      2.321      0.020       0.041       0.490
# Age             0.0402      0.009      4.517      0.000       0.023       0.058
# ===============================================================================
#
# Relative Risks (exponentiated coefficients):
# Intercept      0.007924
# Sex[T.Male]    0.903087
# cluster        1.304346
# Age            1.040969
# dtype: float64

# %% [markdown]
# ## 5. Log Regression

# %%
logR_columns = ["subject_id", "Age", "Sex", "28d_mortality", "hospital_mortality", "vfds_bronch"]
logR_df = pd.merge(df_raw[logR_columns], df_biomarker, on='subject_id', how='inner')
logR_df.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)
logR_df.drop(columns=["Unnamed: 0"], inplace=True)
logR_df['vfds_bronch_category'] = logR_df['vfds_bronch'].apply(categorize_vfds_bronch)
logR_df['vfds_bronch_category'] = pd.Categorical(logR_df['vfds_bronch_category'], ordered=True)

# %%
run_logistic_regression(data=logR_df, formula='hospital_mortality ~ cluster')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  354
# Model:                            GLM   Df Residuals:                      352
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -167.67
# Date:                Fri, 07 Mar 2025   Deviance:                       335.34
# Time:                        06:47:25   Pearson chi2:                     355.
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.01464
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.1344      0.343     -6.219      0.000      -2.807      -1.462
# cluster        0.2602      0.118      2.205      0.027       0.029       0.492
# ==============================================================================
#
# Odds Ratios:
# Intercept    0.118320
# cluster      1.297224
# dtype: float64

# %%
run_logistic_regression(data=logR_df, formula='hospital_mortality ~ cluster + Age + Sex')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  354
# Model:                            GLM   Df Residuals:                      350
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -154.63
# Date:                Fri, 07 Mar 2025   Deviance:                       309.25
# Time:                        06:48:19   Pearson chi2:                     336.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.08465
# Covariance Type:                  HC0
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -4.0535      0.684     -5.930      0.000      -5.393      -2.714
# Sex[T.Male]    -0.5432      0.318     -1.709      0.088      -1.166       0.080
# cluster         0.2999      0.122      2.464      0.014       0.061       0.538
# Age             0.0414      0.009      4.521      0.000       0.023       0.059
# ===============================================================================
#
# Odds Ratios:
# Intercept      0.017361
# Sex[T.Male]    0.580909
# cluster        1.349733
# Age            1.042248
# dtype: float64

# %%
# Fit ordinal logistic regression model in this case
model = OrderedModel.from_formula("vfds_bronch_category ~ cluster", logR_df)
result = model.fit(method='bfgs')
print(result.summary())

# Get odds ratios
print("\nOdds Ratios:")
print(np.exp(result.params))
# Out:
# Optimization terminated successfully.
#          Current function value: 1.295713
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
#                               OrderedModel Results
# ================================================================================
# Dep. Variable:     vfds_bronch_category   Log-Likelihood:                -458.68
# Model:                     OrderedModel   AIC:                             925.4
# Method:              Maximum Likelihood   BIC:                             940.8
# Date:                  Fri, 07 Mar 2025
# Time:                          07:01:24
# No. Observations:                   354
# Df Residuals:                       350
# Df Model:                             1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# cluster       -0.1028      0.049     -2.102      0.036      -0.199      -0.007
# 1/2           -0.5535      0.137     -4.029      0.000      -0.823      -0.284
# 2/3           -1.3142      0.156     -8.405      0.000      -1.621      -1.008
# 3/4           -0.3914      0.095     -4.131      0.000      -0.577      -0.206
# ==============================================================================
#
# Odds Ratios:
# cluster    0.902297
# 1/2        0.574930
# 2/3        0.268690
# 3/4        0.676096
# dtype: float64

# %% [markdown]
# ## 6. Correlation with Pathogen

# %%
#correlation_columns = list(col for col in df_raw.columns if col.startswith('primary'))
correlation_columns = ["primary_organism_colony_count_b1_datetime"]
df_pathogen_correlation = df_raw[correlation_columns]
df_pathogen_correlation["clusters"] = df_biomarker["Cluster"]

df_pathogen_correlation
# Out:
#      primary_organism_colony_count_b1_datetime  clusters
# 0                                          NaN         1
# 1                                      12000.0         2
# 2                                      15000.0         3
# 3                                      10000.0         0
# 4                                          NaN         0
# ..                                         ...       ...
# 461                                        NaN         3
# 462                                    30000.0         0
# 463                                     5000.0         1
# 464                                        NaN         0
# 465                                        NaN         1
#
# [466 rows x 2 columns]

# %%
df_pathogen_correlation["primary_organism_colony_count_b1_datetime"].corr(df_pathogen_correlation["clusters"], method='spearman')
# Out:
# np.float64(-0.020735540150513047)

# %% [markdown]
# ## 7. Save the dataset (subject_id, clusters)

# %%
#correlation_columns = list(col for col in df_raw.columns if col.startswith('primary'))
subject_id = ["subject_id"]
df_subject_id = df_raw[subject_id]
df_subject_id["clusters"] = df_biomarker["Cluster"]

df_subject_id.head()
# Out:
#   subject_id  clusters
# 0       3901         1
# 1       3695         2
# 2       4097         3
# 3       3738         0
# 4       3791         0

# %%
df_subject_id.to_csv("../data/clean_data/subject_id_with_clusters.csv", index=False)

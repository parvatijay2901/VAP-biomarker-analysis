# %% [markdown]
# # Some stats
#
# ## 1. Import necessary libraries, have function definitions

# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import mannwhitneyu, kruskal, fisher_exact, chi2_contingency
from statsmodels.miscmodels.ordinal_model import OrderedModel

from pprint import pprint

import warnings
warnings.filterwarnings("ignore")

# %%
# Define vfds groups
def categorize_vfds_bronch(x):
    if 0 <= x <= 7:
        return 1
    elif 8 <= x <= 14:
        return 2
    elif 15 <= x <= 21:
        return 3
    elif 22 <= x <= 28:
        return 4
    else:
        return None

# %%
# Define vfds groups
def categorize_cluster(x):
    if x == 1:
        return 5
    else:
        return x

# %%
# Fit a logistic regression model with robust standard errors
def run_logistic_regression(data, formula, cluster_name='cluster', reference_cluster=2):

    data[cluster_name] =  data[cluster_name].apply(categorize_cluster)
    data[cluster_name] = data[cluster_name].astype('category')
    # data[cluster_name] = data[cluster_name].cat.reorder_categories(
    #         sorted(data[cluster_name].unique(), key=lambda x: x != reference_cluster), 
    #         ordered=True
    #     )

    model = smf.glm(formula=formula, 
                    data=data, 
                    family=sm.families.Binomial()).fit(cov_type='HC0')  # HC0 = Robust SEs
    
    print(model.summary())

    # Compute Odds Ratios (exponentiate the coefficients)
    odds_ratios = np.exp(model.params)
    
    print("\nOdds Ratios:")
    print(odds_ratios)

    print("\nP-values:")
    print(model.pvalues)
    
    return model

# %%
# Fit a modified Poisson regression model with Huber-White robust standard error.
def run_modified_poisson_regression(data, formula, cluster_name='cluster', reference_cluster=2):
    
    data[cluster_name] =  data[cluster_name].apply(categorize_cluster)
    data[cluster_name] = data[cluster_name].astype('category')
    # data[cluster_name] = data[cluster_name].cat.reorder_categories(
    #         sorted(data[cluster_name].unique(), key=lambda x: x != reference_cluster), 
    #         ordered=True
    #     )

    # Fit the Poisson model with robust standard errors
    model = smf.glm(formula=formula, 
                    data=data, 
                    family=sm.families.Poisson()).fit(cov_type='HC0')
    
    print(model.summary())
    
    # Calculate and print Relative Risks (Exponentiated Coefficients)
    relative_risks = np.exp(model.params)
    print("\nRelative Risks (exponentiated coefficients):")
    print(relative_risks)

# %%
# Create a summary table for selected variables, stratified by a grouping variable.
def create_summary_table(df, group_var='cluster'):

    continuous_vars = ['BMI', 'Age', 'bronch_day_1', 'sofa_icu', 'sofa_b1', 'vfds_bronch']
    categorical_vars = ['Sex', 'Race', 'Ethnicity', 'mortality_28d', 'hospital_mortality', 'icu_mortality']
    
    summary = {'continuous': {}, 'categorical': {}}
    
    # Determine groups
    groups = sorted(df[group_var].dropna().unique())
    n_groups = len(groups)
    
    # 1. Continuous variables
    for var in continuous_vars:
        # Overall median, IQR
        overall_median = df[var].median()
        overall_iqr = (df[var].quantile(0.25), df[var].quantile(0.75))
        
        # Group-specific median, IQR
        group_summary = {}
        group_series = []
        for g in groups:
            grp_vals = df.loc[df[group_var] == g, var].dropna()
            group_series.append(grp_vals)
            
            if len(grp_vals) > 0:
                g_median = grp_vals.median()
                g_iqr = (grp_vals.quantile(0.25), grp_vals.quantile(0.75))
                group_summary[g] = f"{g_median:.1f} ({g_iqr[0]:.1f} to {g_iqr[1]:.1f})"
            else:
                group_summary[g] = "NA (NA to NA)"
        
        # p-value: Mann-Whitney if 2 groups, Kruskal-Wallis if >2
        if n_groups == 2:
            try:
                stat, pval = mannwhitneyu(group_series[0], group_series[1], alternative='two-sided')
            except:
                pval = np.nan
        else:
            try:
                stat, pval = kruskal(*group_series)
            except:
                pval = np.nan
        
        summary['continuous'][var] = {
            'Overall': f"{overall_median:.1f} ({overall_iqr[0]:.1f} to {overall_iqr[1]:.1f})",
            'By Group': group_summary,
            'p-value': pval
        }

    # 2. Categorical variables
    for var in categorical_vars:
        summary['categorical'][var] = {'By Category': {}}
        
        # Identify all categories
        categories = df[var].dropna().unique()
        
        for cat in categories:
            row_dict = {}
            # Overall count/percent for this category
            is_cat = (df[var] == cat)
            cat_count = is_cat.sum()
            total_count = df[var].notna().sum()
            cat_percent = 100.0 * cat_count / total_count if total_count else 0
            row_dict["Overall"] = f"{cat_count} ({cat_percent:.1f}%)"
            
            # Group-specific counts/percents
            cat_counts = []
            not_cat_counts = []
            for g in groups:
                grp_df = df[df[group_var] == g]
                grp_cat_count = (grp_df[var] == cat).sum()
                grp_total = grp_df[var].notna().sum()
                grp_percent = 100.0 * grp_cat_count / grp_total if grp_total else 0
                row_dict[g] = f"{grp_cat_count} ({grp_percent:.1f}%)"
                
                # For building the 2-row x n-groups table
                cat_counts.append(grp_cat_count)
                not_cat_counts.append(grp_total - grp_cat_count)
            
            # p-value for "this category vs. not this category" across the groups
            contingency = np.array([cat_counts, not_cat_counts])
            if n_groups == 2:
                # Fisher's exact for 2 groups
                try:
                    _, p_val = fisher_exact(contingency)
                except:
                    p_val = np.nan
            else:
                # Chi-square for >2 groups
                try:
                    _, p_val, _, _ = chi2_contingency(contingency)
                except:
                    p_val = np.nan
            
            row_dict["p-value"] = p_val
            
            summary['categorical'][var]['By Category'][cat] = row_dict
    
    return summary

# %% [markdown]
# ## 2. Load the data
#
# First, load the raw data

# %%
file_path = "../../data/raw_data/Daily_merged_2025-02-28(in).csv"
sheet_name = "in"

# read the raw data
df_raw = pd.read_csv(file_path)
df_raw = df_raw[df_raw["cohort"] == "vap"]
df_raw = df_raw[df_raw["repeat"] == 1]
df_raw = df_raw.dropna(subset=['balf_PD-L1_V1_imputed'])
df_raw["subject_id"] = df_raw["subject_id"].astype(str)
df_raw = df_raw.reset_index(drop=True)
print(df_raw.shape)
df_raw.head()
# Out:
# (466, 2675)
#                                            merged_id subject_id cohort  \
# 0  0060cb7f038fc2524edc6c5fd51c1311f7dab5fd460126...       3901    vap
# 1  010a9d89899aff76eca797c6b0b88baa321a7c465cc5aa...       3695    vap
# 2  0138d106c8ad7c0ae0712e4ea5a8b9d5d1c4410d2db4bc...       4097    vap
# 3  0196c36dc652445d5d25d38bcbee46b0e2e40d91884fa9...       3738    vap
# 4  01cc89f062a95ba91cd58800437cb2ef29b48b867701b6...       3791    vap
#
#    repeat                                         encoded_id  \
# 0       1  bdcedd0872be7c0678cfe00884f0ef3b7f833e00937b48...
# 1       1  c1738fe9ecd511185d729136745c384958e6e009e47080...
# 2       1  ab1b10eb5052132cfa1465402af4d3af7fd4f008c1084a...
# 3       1  6f5dff78f3c7c63081fcbced005868465e7f1d9aa1f640...
# 4       1  09b4890ada6e16740d1a18a7ba5578e02efcb5d1821d89...
#
#                  true_admit_date              admit_date_redcap  \
# 0  2021-02-01T00:00:00.000000000  2021-02-01T00:00:00.000000000
# 1  2018-07-02T00:00:00.000000000  2018-07-02T00:00:00.000000000
# 2  2023-08-06T00:00:00.000000000  2023-08-06T00:00:00.000000000
# 3  2019-06-22T00:00:00.000000000  2019-06-22T00:00:00.000000000
# 4  2020-02-09T00:00:00.000000000  2020-02-09T00:00:00.000000000
#
#              icu_admit_date_iths           icu_admit_source icu_admit_type  \
# 0  2021-02-01T21:39:00.000000000       Emergency department       Surgical
# 1  2018-07-03T23:50:00.000000000       Emergency department          Neuro
# 2  2023-08-06T04:48:00.000000000       Emergency department       Surgical
# 3  2019-07-01T23:52:00.000000000  Outside hospital transfer       Surgical
# 4  2020-02-08T18:06:00.000000000       Emergency department          Neuro
#
#    ... pc_IL-10_proinf_V1_imputed pc_IL-12p70_proinf_V1_imputed  \
# 0  ...                        NaN                           NaN
# 1  ...                        NaN                           NaN
# 2  ...                        NaN                           NaN
# 3  ...                        NaN                           NaN
# 4  ...                        NaN                           NaN
#
#    pc_IL-13_proinf_V1_imputed pc_IL-1?_proinf_V1_imputed  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   pc_IL-2_proinf_V1_imputed pc_IL-4_proinf_V1_imputed  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   pc_IL-6_proinf_V1_imputed pc_TNF-?_proinf_V1_imputed pc_sRAGE_V1_imputed  \
# 0                       NaN                        NaN                 NaN
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
#
#   pc_TNF-RI_V1_imputed
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 2675 columns]

# %% [markdown]
# Then, let us load the biomarker data that also has the clusters

# %%
# Biomarker data with clusters
file_path = "../../data/clean_data/vap_cluster_assignments_k4_ted.csv"
df_biomarker = pd.read_csv(file_path)
df_biomarker["subject_id"] = df_biomarker["subject_id"].astype(str)
df_biomarker.drop(columns=["Unnamed: 0"], inplace=True)
print(df_biomarker.shape)
df_biomarker.head()
# Out:
# (466, 2)
#   subject_id  cluster
# 0       3901        3
# 1       3695        4
# 2       4097        4
# 3       3738        3
# 4       3791        4

# %%
# # Biomarker data (after removing not correlated variables) with clusters
# file_path = "../data/clean_data/scaled_biomarker_data_notcorrelated_with_clusters.csv"
# df_biomarker_notcorrelated = pd.read_csv(file_path)
# df_biomarker_notcorrelated.head()

# %%
table1_columns = ['subject_id', 'BMI', 'Age', 'bronch_day_1', 'sofa_icu', 'sofa_b1', 'Sex', 'Race', 
               'Ethnicity', '28d_mortality', 'hospital_mortality', 'icu_mortality', 'vfds_bronch']
table1_df_correlated = pd.merge(df_raw[table1_columns], df_biomarker, on='subject_id', how='outer')
table1_df_correlated.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)

# %% [markdown]
# ## 3. Participant Characteristics

# %%
summary_table = create_summary_table(table1_df_correlated)
pprint(summary_table)
# Out:
# {'categorical': {'Ethnicity': {'By Category': {'Hispanic or Latino': {np.int64(1): '0 '
#                                                                                    '(0.0%)',
#                                                                       np.int64(2): '1 '
#                                                                                    '(1.8%)',
#                                                                       np.int64(3): '0 '
#                                                                                    '(0.0%)',
#                                                                       np.int64(4): '0 '
#                                                                                    '(0.0%)',
#                                                                       'Overall': '1 '
#                                                                                  '(0.2%)',
#                                                                       'p-value': np.float64(0.057846987854163215)},
#                                                'Hispanic or Latino/a or Latinx': {np.int64(1): '15 '
#                                                                                                '(9.4%)',
#                                                                                   np.int64(2): '5 '
#                                                                                                '(9.1%)',
#                                                                                   np.int64(3): '15 '
#                                                                                                '(11.5%)',
#                                                                                   np.int64(4): '8 '
#                                                                                                '(6.6%)',
#                                                                                   'Overall': '43 '
#                                                                                              '(9.2%)',
#                                                                                   'p-value': np.float64(0.6099826391077428)},
#                                                'NOT Hispanic or Latino': {np.int64(1): '4 '
#                                                                                        '(2.5%)',
#                                                                           np.int64(2): '0 '
#                                                                                        '(0.0%)',
#                                                                           np.int64(3): '1 '
#                                                                                        '(0.8%)',
#                                                                           np.int64(4): '2 '
#                                                                                        '(1.7%)',
#                                                                           'Overall': '7 '
#                                                                                      '(1.5%)',
#                                                                           'p-value': np.float64(0.4925034617920233)},
#                                                'Non-Hispanic or Latino/a or Latinx': {np.int64(1): '137 '
#                                                                                                    '(85.6%)',
#                                                                                       np.int64(2): '47 '
#                                                                                                    '(85.5%)',
#                                                                                       np.int64(3): '111 '
#                                                                                                    '(85.4%)',
#                                                                                       np.int64(4): '104 '
#                                                                                                    '(86.0%)',
#                                                                                       'Overall': '399 '
#                                                                                                  '(85.6%)',
#                                                                                       'p-value': np.float64(0.9993714470411799)},
#                                                'Patient declined to respond': {np.int64(1): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(2): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(3): '0 '
#                                                                                             '(0.0%)',
#                                                                                np.int64(4): '1 '
#                                                                                             '(0.8%)',
#                                                                                'Overall': '1 '
#                                                                                           '(0.2%)',
#                                                                                'p-value': np.float64(0.4141424388532814)},
#                                                'Unknown to patient': {np.int64(1): '4 '
#                                                                                    '(2.5%)',
#                                                                       np.int64(2): '2 '
#                                                                                    '(3.6%)',
#                                                                       np.int64(3): '3 '
#                                                                                    '(2.3%)',
#                                                                       np.int64(4): '6 '
#                                                                                    '(5.0%)',
#                                                                       'Overall': '15 '
#                                                                                  '(3.2%)',
#                                                                       'p-value': np.float64(0.6109531542107116)}}},
#                  'Race': {'By Category': {'Alaska Native': {np.int64(1): '1 '
#                                                                          '(0.6%)',
#                                                             np.int64(2): '0 '
#                                                                          '(0.0%)',
#                                                             np.int64(3): '0 '
#                                                                          '(0.0%)',
#                                                             np.int64(4): '0 '
#                                                                          '(0.0%)',
#                                                             'Overall': '1 '
#                                                                        '(0.2%)',
#                                                             'p-value': np.float64(0.5898930690099997)},
#                                           'American Indian': {np.int64(1): '0 '
#                                                                            '(0.0%)',
#                                                               np.int64(2): '0 '
#                                                                            '(0.0%)',
#                                                               np.int64(3): '1 '
#                                                                            '(0.8%)',
#                                                               np.int64(4): '0 '
#                                                                            '(0.0%)',
#                                                               'Overall': '1 '
#                                                                          '(0.2%)',
#                                                               'p-value': np.float64(0.45921482946919145)},
#                                           'American Indian or Native Alaskan': {np.int64(1): '5 '
#                                                                                              '(3.1%)',
#                                                                                 np.int64(2): '2 '
#                                                                                              '(3.6%)',
#                                                                                 np.int64(3): '3 '
#                                                                                              '(2.3%)',
#                                                                                 np.int64(4): '5 '
#                                                                                              '(4.1%)',
#                                                                                 'Overall': '15 '
#                                                                                            '(3.2%)',
#                                                                                 'p-value': np.float64(0.871843390799038)},
#                                           'American Indian or Native Alaskan,Black or African-American': {np.int64(1): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           np.int64(2): '1 '
#                                                                                                                        '(1.8%)',
#                                                                                                           np.int64(3): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           np.int64(4): '0 '
#                                                                                                                        '(0.0%)',
#                                                                                                           'Overall': '1 '
#                                                                                                                      '(0.2%)',
#                                                                                                           'p-value': np.float64(0.057846987854163215)},
#                                           'American Indian or Native Alaskan,White': {np.int64(1): '2 '
#                                                                                                    '(1.2%)',
#                                                                                       np.int64(2): '0 '
#                                                                                                    '(0.0%)',
#                                                                                       np.int64(3): '0 '
#                                                                                                    '(0.0%)',
#                                                                                       np.int64(4): '1 '
#                                                                                                    '(0.8%)',
#                                                                                       'Overall': '3 '
#                                                                                                  '(0.6%)',
#                                                                                       'p-value': np.float64(0.5356764241420204)},
#                                           'Another Race': {np.int64(1): '0 '
#                                                                         '(0.0%)',
#                                                            np.int64(2): '1 '
#                                                                         '(1.8%)',
#                                                            np.int64(3): '1 '
#                                                                         '(0.8%)',
#                                                            np.int64(4): '1 '
#                                                                         '(0.8%)',
#                                                            'Overall': '3 '
#                                                                       '(0.6%)',
#                                                            'p-value': np.float64(0.5091228870911035)},
#                                           'Asian': {np.int64(1): '11 (6.9%)',
#                                                     np.int64(2): '6 (10.9%)',
#                                                     np.int64(3): '9 (6.9%)',
#                                                     np.int64(4): '5 (4.1%)',
#                                                     'Overall': '31 (6.7%)',
#                                                     'p-value': np.float64(0.4120273774382869)},
#                                           'Asian,Native Hawaiian or Pacific Islander': {np.int64(1): '1 '
#                                                                                                      '(0.6%)',
#                                                                                         np.int64(2): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         np.int64(3): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         np.int64(4): '0 '
#                                                                                                      '(0.0%)',
#                                                                                         'Overall': '1 '
#                                                                                                    '(0.2%)',
#                                                                                         'p-value': np.float64(0.5898930690099997)},
#                                           'Asian,Pacific Islander': {np.int64(1): '0 '
#                                                                                   '(0.0%)',
#                                                                      np.int64(2): '1 '
#                                                                                   '(1.8%)',
#                                                                      np.int64(3): '0 '
#                                                                                   '(0.0%)',
#                                                                      np.int64(4): '0 '
#                                                                                   '(0.0%)',
#                                                                      'Overall': '1 '
#                                                                                 '(0.2%)',
#                                                                      'p-value': np.float64(0.057846987854163215)},
#                                           'Asian,White': {np.int64(1): '1 '
#                                                                        '(0.6%)',
#                                                           np.int64(2): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(3): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(4): '0 '
#                                                                        '(0.0%)',
#                                                           'Overall': '1 (0.2%)',
#                                                           'p-value': np.float64(0.5898930690099997)},
#                                           'Black or African American': {np.int64(1): '1 '
#                                                                                      '(0.6%)',
#                                                                         np.int64(2): '0 '
#                                                                                      '(0.0%)',
#                                                                         np.int64(3): '1 '
#                                                                                      '(0.8%)',
#                                                                         np.int64(4): '1 '
#                                                                                      '(0.8%)',
#                                                                         'Overall': '3 '
#                                                                                    '(0.6%)',
#                                                                         'p-value': np.float64(0.929225043425242)},
#                                           'Black or African-American': {np.int64(1): '17 '
#                                                                                      '(10.6%)',
#                                                                         np.int64(2): '5 '
#                                                                                      '(9.1%)',
#                                                                         np.int64(3): '11 '
#                                                                                      '(8.5%)',
#                                                                         np.int64(4): '11 '
#                                                                                      '(9.1%)',
#                                                                         'Overall': '44 '
#                                                                                    '(9.4%)',
#                                                                         'p-value': np.float64(0.9332590467886193)},
#                                           'Black or African-American,Asian': {np.int64(1): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(2): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(3): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(4): '1 '
#                                                                                            '(0.8%)',
#                                                                               'Overall': '1 '
#                                                                                          '(0.2%)',
#                                                                               'p-value': np.float64(0.4141424388532814)},
#                                           'Black or African-American,Asian,White': {np.int64(1): '0 '
#                                                                                                  '(0.0%)',
#                                                                                     np.int64(2): '1 '
#                                                                                                  '(1.8%)',
#                                                                                     np.int64(3): '0 '
#                                                                                                  '(0.0%)',
#                                                                                     np.int64(4): '1 '
#                                                                                                  '(0.8%)',
#                                                                                     'Overall': '2 '
#                                                                                                '(0.4%)',
#                                                                                     'p-value': np.float64(0.24267967061523188)},
#                                           'Black or African-American,Unavailable or Unknown': {np.int64(1): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                np.int64(2): '1 '
#                                                                                                             '(1.8%)',
#                                                                                                np.int64(3): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                np.int64(4): '0 '
#                                                                                                             '(0.0%)',
#                                                                                                'Overall': '1 '
#                                                                                                           '(0.2%)',
#                                                                                                'p-value': np.float64(0.057846987854163215)},
#                                           'Black or African-American,White': {np.int64(1): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(2): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(3): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(4): '1 '
#                                                                                            '(0.8%)',
#                                                                               'Overall': '1 '
#                                                                                          '(0.2%)',
#                                                                               'p-value': np.float64(0.4141424388532814)},
#                                           'Declined to Answer': {np.int64(1): '0 '
#                                                                               '(0.0%)',
#                                                                  np.int64(2): '0 '
#                                                                               '(0.0%)',
#                                                                  np.int64(3): '2 '
#                                                                               '(1.5%)',
#                                                                  np.int64(4): '0 '
#                                                                               '(0.0%)',
#                                                                  'Overall': '2 '
#                                                                             '(0.4%)',
#                                                                  'p-value': np.float64(0.15829896249905734)},
#                                           'Declined to Answer,Black or African-American': {np.int64(1): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            np.int64(2): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            np.int64(3): '1 '
#                                                                                                         '(0.8%)',
#                                                                                            np.int64(4): '0 '
#                                                                                                         '(0.0%)',
#                                                                                            'Overall': '1 '
#                                                                                                       '(0.2%)',
#                                                                                            'p-value': np.float64(0.45921482946919145)},
#                                           'Declined to Answer,White': {np.int64(1): '0 '
#                                                                                     '(0.0%)',
#                                                                        np.int64(2): '0 '
#                                                                                     '(0.0%)',
#                                                                        np.int64(3): '1 '
#                                                                                     '(0.8%)',
#                                                                        np.int64(4): '0 '
#                                                                                     '(0.0%)',
#                                                                        'Overall': '1 '
#                                                                                   '(0.2%)',
#                                                                        'p-value': np.float64(0.45921482946919145)},
#                                           'Native Hawaiian or Pacific Islander': {np.int64(1): '4 '
#                                                                                                '(2.5%)',
#                                                                                   np.int64(2): '0 '
#                                                                                                '(0.0%)',
#                                                                                   np.int64(3): '3 '
#                                                                                                '(2.3%)',
#                                                                                   np.int64(4): '1 '
#                                                                                                '(0.8%)',
#                                                                                   'Overall': '8 '
#                                                                                              '(1.7%)',
#                                                                                   'p-value': np.float64(0.4973769263444522)},
#                                           'Unavailable or Unknown': {np.int64(1): '5 '
#                                                                                   '(3.1%)',
#                                                                      np.int64(2): '1 '
#                                                                                   '(1.8%)',
#                                                                      np.int64(3): '1 '
#                                                                                   '(0.8%)',
#                                                                      np.int64(4): '3 '
#                                                                                   '(2.5%)',
#                                                                      'Overall': '10 '
#                                                                                 '(2.1%)',
#                                                                      'p-value': np.float64(0.573251647669424)},
#                                           'Unavailable or Unknown,American Indian or Native Alaskan,White': {np.int64(1): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(2): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(3): '0 '
#                                                                                                                           '(0.0%)',
#                                                                                                              np.int64(4): '1 '
#                                                                                                                           '(0.8%)',
#                                                                                                              'Overall': '1 '
#                                                                                                                         '(0.2%)',
#                                                                                                              'p-value': np.float64(0.4141424388532814)},
#                                           'Unavailable or Unknown,Unable to Collect': {np.int64(1): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        np.int64(2): '1 '
#                                                                                                     '(1.8%)',
#                                                                                        np.int64(3): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        np.int64(4): '0 '
#                                                                                                     '(0.0%)',
#                                                                                        'Overall': '1 '
#                                                                                                   '(0.2%)',
#                                                                                        'p-value': np.float64(0.057846987854163215)},
#                                           'Unavailable or Unknown,White': {np.int64(1): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(2): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(3): '1 '
#                                                                                         '(0.8%)',
#                                                                            np.int64(4): '0 '
#                                                                                         '(0.0%)',
#                                                                            'Overall': '1 '
#                                                                                       '(0.2%)',
#                                                                            'p-value': np.float64(0.45921482946919145)},
#                                           'White': {np.int64(1): '111 (69.4%)',
#                                                     np.int64(2): '34 (61.8%)',
#                                                     np.int64(3): '94 (72.3%)',
#                                                     np.int64(4): '87 (71.9%)',
#                                                     'Overall': '326 (70.0%)',
#                                                     'p-value': np.float64(0.5089741329728275)},
#                                           'White,Asian': {np.int64(1): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(2): '1 '
#                                                                        '(1.8%)',
#                                                           np.int64(3): '0 '
#                                                                        '(0.0%)',
#                                                           np.int64(4): '0 '
#                                                                        '(0.0%)',
#                                                           'Overall': '1 (0.2%)',
#                                                           'p-value': np.float64(0.057846987854163215)},
#                                           'White,Black or African-American': {np.int64(1): '1 '
#                                                                                            '(0.6%)',
#                                                                               np.int64(2): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(3): '0 '
#                                                                                            '(0.0%)',
#                                                                               np.int64(4): '1 '
#                                                                                            '(0.8%)',
#                                                                               'Overall': '2 '
#                                                                                          '(0.4%)',
#                                                                               'p-value': np.float64(0.7083908095837073)},
#                                           'White,Unavailable or Unknown': {np.int64(1): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(2): '0 '
#                                                                                         '(0.0%)',
#                                                                            np.int64(3): '1 '
#                                                                                         '(0.8%)',
#                                                                            np.int64(4): '1 '
#                                                                                         '(0.8%)',
#                                                                            'Overall': '2 '
#                                                                                       '(0.4%)',
#                                                                            'p-value': np.float64(0.6313165899522297)}}},
#                  'Sex': {'By Category': {'Female': {np.int64(1): '43 (26.9%)',
#                                                     np.int64(2): '18 (32.7%)',
#                                                     np.int64(3): '32 (24.6%)',
#                                                     np.int64(4): '28 (23.1%)',
#                                                     'Overall': '121 (26.0%)',
#                                                     'p-value': np.float64(0.5718714336331276)},
#                                          'Male': {np.int64(1): '117 (73.1%)',
#                                                   np.int64(2): '37 (67.3%)',
#                                                   np.int64(3): '98 (75.4%)',
#                                                   np.int64(4): '93 (76.9%)',
#                                                   'Overall': '345 (74.0%)',
#                                                   'p-value': np.float64(0.5718714336331276)}}},
#                  'hospital_mortality': {'By Category': {np.int64(0): {np.int64(1): '134 '
#                                                                                    '(83.8%)',
#                                                                       np.int64(2): '47 '
#                                                                                    '(85.5%)',
#                                                                       np.int64(3): '101 '
#                                                                                    '(77.7%)',
#                                                                       np.int64(4): '88 '
#                                                                                    '(72.7%)',
#                                                                       'Overall': '370 '
#                                                                                  '(79.4%)',
#                                                                       'p-value': np.float64(0.0854580071469695)},
#                                                         np.int64(1): {np.int64(1): '26 '
#                                                                                    '(16.2%)',
#                                                                       np.int64(2): '8 '
#                                                                                    '(14.5%)',
#                                                                       np.int64(3): '29 '
#                                                                                    '(22.3%)',
#                                                                       np.int64(4): '33 '
#                                                                                    '(27.3%)',
#                                                                       'Overall': '96 '
#                                                                                  '(20.6%)',
#                                                                       'p-value': np.float64(0.0854580071469695)}}},
#                  'icu_mortality': {'By Category': {np.int64(0): {np.int64(1): '137 '
#                                                                               '(85.6%)',
#                                                                  np.int64(2): '49 '
#                                                                               '(89.1%)',
#                                                                  np.int64(3): '113 '
#                                                                               '(86.9%)',
#                                                                  np.int64(4): '96 '
#                                                                               '(79.3%)',
#                                                                  'Overall': '395 '
#                                                                             '(84.8%)',
#                                                                  'p-value': np.float64(0.24921008635896866)},
#                                                    np.int64(1): {np.int64(1): '23 '
#                                                                               '(14.4%)',
#                                                                  np.int64(2): '6 '
#                                                                               '(10.9%)',
#                                                                  np.int64(3): '17 '
#                                                                               '(13.1%)',
#                                                                  np.int64(4): '25 '
#                                                                               '(20.7%)',
#                                                                  'Overall': '71 '
#                                                                             '(15.2%)',
#                                                                  'p-value': np.float64(0.24921008635896866)}}},
#                  'mortality_28d': {'By Category': {np.int64(0): {np.int64(1): '142 '
#                                                                               '(88.8%)',
#                                                                  np.int64(2): '49 '
#                                                                               '(89.1%)',
#                                                                  np.int64(3): '110 '
#                                                                               '(84.6%)',
#                                                                  np.int64(4): '96 '
#                                                                               '(79.3%)',
#                                                                  'Overall': '397 '
#                                                                             '(85.2%)',
#                                                                  'p-value': np.float64(0.13341179610381992)},
#                                                    np.int64(1): {np.int64(1): '18 '
#                                                                               '(11.2%)',
#                                                                  np.int64(2): '6 '
#                                                                               '(10.9%)',
#                                                                  np.int64(3): '20 '
#                                                                               '(15.4%)',
#                                                                  np.int64(4): '25 '
#                                                                               '(20.7%)',
#                                                                  'Overall': '69 '
#                                                                             '(14.8%)',
#                                                                  'p-value': np.float64(0.13341179610381992)}}}},
#  'continuous': {'Age': {'By Group': {np.int64(1): '55.5 (38.2 to 65.0)',
#                                      np.int64(2): '38.7 (28.3 to 54.6)',
#                                      np.int64(3): '52.6 (38.9 to 64.1)',
#                                      np.int64(4): '49.4 (34.5 to 63.0)'},
#                         'Overall': '51.5 (35.9 to 63.7)',
#                         'p-value': np.float64(0.0027948585583555887)},
#                 'BMI': {'By Group': {np.int64(1): '28.7 (24.4 to 34.4)',
#                                      np.int64(2): '26.3 (23.3 to 29.2)',
#                                      np.int64(3): '28.2 (23.8 to 33.2)',
#                                      np.int64(4): '26.5 (24.1 to 31.1)'},
#                         'Overall': '27.4 (24.0 to 32.4)',
#                         'p-value': np.float64(0.06089415957567891)},
#                 'bronch_day_1': {'By Group': {np.int64(1): '7.0 (4.0 to 13.0)',
#                                               np.int64(2): '5.0 (3.0 to 7.0)',
#                                               np.int64(3): '8.0 (5.0 to 15.0)',
#                                               np.int64(4): '7.0 (4.0 to 11.0)'},
#                                  'Overall': '7.0 (4.0 to 12.0)',
#                                  'p-value': np.float64(0.00029441795706579787)},
#                 'sofa_b1': {'By Group': {np.int64(1): '6.0 (4.0 to 8.0)',
#                                          np.int64(2): '7.0 (5.0 to 9.0)',
#                                          np.int64(3): '5.0 (4.0 to 7.0)',
#                                          np.int64(4): '6.0 (4.0 to 8.0)'},
#                             'Overall': '6.0 (4.0 to 8.0)',
#                             'p-value': np.float64(0.0031808722084780408)},
#                 'sofa_icu': {'By Group': {np.int64(1): '6.0 (3.0 to 8.0)',
#                                           np.int64(2): '7.0 (4.0 to 10.0)',
#                                           np.int64(3): '6.0 (3.0 to 9.0)',
#                                           np.int64(4): '6.0 (3.0 to 9.0)'},
#                              'Overall': '6.0 (3.0 to 9.0)',
#                              'p-value': np.float64(0.5343048985780319)},
#                 'vfds_bronch': {'By Group': {np.int64(1): '16.0 (0.0 to 22.0)',
#                                              np.int64(2): '16.0 (0.0 to 23.0)',
#                                              np.int64(3): '14.0 (0.0 to 21.0)',
#                                              np.int64(4): '9.0 (0.0 to 19.0)'},
#                                 'Overall': '14.0 (0.0 to 21.0)',
#                                 'p-value': np.float64(0.04827752284236929)}}}

# %%
# summary_table = create_summary_table(table1_df_notcorrelated)
# pprint(summary_table)

# %% [markdown]
# ## 4. Relative Risk

# %%
RR_columns = ["subject_id", "Age", "Sex", "28d_mortality", "hospital_mortality", "vfds_bronch"]
RR_df = pd.merge(df_raw[RR_columns], df_biomarker, on='subject_id', how='inner')
RR_df.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)

RR_df['vfds_bronch_category'] = RR_df['vfds_bronch'].apply(categorize_vfds_bronch)
RR_df['vfds_bronch_category'] = pd.Categorical(RR_df['vfds_bronch_category'], ordered=True)

# %%
run_modified_poisson_regression(data=RR_df, formula='hospital_mortality ~ cluster + Sex + Age')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  466
# Model:                            GLM   Df Residuals:                      460
# Model Family:                 Poisson   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -233.53
# Date:                Sat, 08 Mar 2025   Deviance:                       275.05
# Time:                        12:30:14   Pearson chi2:                     361.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.05887
# Covariance Type:                  HC0
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.2289      0.496     -6.507      0.000      -4.202      -2.256
# cluster[T.3]     0.2128      0.354      0.601      0.548      -0.481       0.906
# cluster[T.4]     0.4630      0.351      1.318      0.188      -0.226       1.152
# cluster[T.5]    -0.1144      0.360     -0.317      0.751      -0.821       0.592
# Sex[T.Male]     -0.1419      0.197     -0.719      0.472      -0.529       0.245
# Age              0.0292      0.006      5.148      0.000       0.018       0.040
# ================================================================================
#
# Relative Risks (exponentiated coefficients):
# Intercept       0.039600
# cluster[T.3]    1.237121
# cluster[T.4]    1.588790
# cluster[T.5]    0.891886
# Sex[T.Male]     0.867724
# Age             1.029591
# dtype: float64

# %%
run_modified_poisson_regression(data=RR_df, formula='mortality_28d ~ cluster + Sex + Age')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          mortality_28d   No. Observations:                  466
# Model:                            GLM   Df Residuals:                      460
# Model Family:                 Poisson   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -185.79
# Date:                Sat, 08 Mar 2025   Deviance:                       233.58
# Time:                        12:30:14   Pearson chi2:                     408.
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.06236
# Covariance Type:                  HC0
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -4.1166      0.637     -6.463      0.000      -5.365      -2.868
# cluster[T.3]     0.0435      0.417      0.104      0.917      -0.774       0.861
# cluster[T.4]     0.3880      0.411      0.944      0.345      -0.418       1.194
# cluster[T.5]    -0.2850      0.429     -0.664      0.506      -1.126       0.556
# Sex[T.Male]      0.0999      0.255      0.392      0.695      -0.400       0.600
# Age              0.0377      0.008      5.014      0.000       0.023       0.052
# ================================================================================
#
# Relative Risks (exponentiated coefficients):
# Intercept       0.016299
# cluster[T.3]    1.044499
# cluster[T.4]    1.474057
# cluster[T.5]    0.752039
# Sex[T.Male]     1.105084
# Age             1.038399
# dtype: float64

# %%
run_modified_poisson_regression(data=RR_df, formula='hospital_mortality ~ cluster + Age + Sex + vfds_bronch_category')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  466
# Model:                            GLM   Df Residuals:                      457
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -177.07
# Date:                Sat, 08 Mar 2025   Deviance:                       162.14
# Time:                        12:30:14   Pearson chi2:                     323.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2614
# Covariance Type:                  HC0
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -1.6756      0.390     -4.300      0.000      -2.439      -0.912
# cluster[T.3]                  0.2907      0.292      0.996      0.319      -0.281       0.863
# cluster[T.4]                  0.3073      0.290      1.061      0.289      -0.260       0.875
# cluster[T.5]                  0.0216      0.299      0.072      0.942      -0.565       0.608
# Sex[T.Male]                  -0.2937      0.163     -1.802      0.072      -0.613       0.026
# vfds_bronch_category[T.2]    -3.1592      0.999     -3.162      0.002      -5.117      -1.201
# vfds_bronch_category[T.3]    -3.2424      0.707     -4.585      0.000      -4.628      -1.856
# vfds_bronch_category[T.4]    -2.7997      0.573     -4.885      0.000      -3.923      -1.677
# Age                           0.0175      0.004      4.007      0.000       0.009       0.026
# =============================================================================================
#
# Relative Risks (exponentiated coefficients):
# Intercept                    0.187191
# cluster[T.3]                 1.337364
# cluster[T.4]                 1.359782
# cluster[T.5]                 1.021838
# Sex[T.Male]                  0.745505
# vfds_bronch_category[T.2]    0.042461
# vfds_bronch_category[T.3]    0.039071
# vfds_bronch_category[T.4]    0.060827
# Age                          1.017703
# dtype: float64

# %% [markdown]
# ## 5. Log Regression

# %%
logR_columns = ["subject_id", "Age", "Sex", "28d_mortality", "hospital_mortality", "vfds_bronch"]
logR_df = pd.merge(df_raw[logR_columns], df_biomarker, on='subject_id', how='inner')
logR_df.rename(columns={"28d_mortality": "mortality_28d"}, inplace=True)
# logR_df['vfds_bronch_category'] = logR_df['vfds_bronch'].apply(categorize_vfds_bronch)
# logR_df['vfds_bronch_category'] = pd.Categorical(logR_df['vfds_bronch_category'], ordered=True)

# %%
run_logistic_regression(data=logR_df, formula='hospital_mortality ~ cluster')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  466
# Model:                            GLM   Df Residuals:                      462
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -233.72
# Date:                Sat, 08 Mar 2025   Deviance:                       467.44
# Time:                        12:30:14   Pearson chi2:                     466.
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.01406
# Covariance Type:                  HC0
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -1.7707      0.382     -4.630      0.000      -2.520      -1.021
# cluster[T.3]     0.5229      0.437      1.197      0.231      -0.333       1.379
# cluster[T.4]     0.7899      0.434      1.822      0.068      -0.060       1.640
# cluster[T.5]     0.1310      0.438      0.299      0.765      -0.728       0.990
# ================================================================================
#
# Odds Ratios:
# Intercept       0.170213
# cluster[T.3]    1.686881
# cluster[T.4]    2.203125
# cluster[T.5]    1.139925
# dtype: float64
#
# P-values:
# Intercept       0.000004
# cluster[T.3]    0.231114
# cluster[T.4]    0.068457
# cluster[T.5]    0.765151
# dtype: float64

# %%
run_logistic_regression(data=logR_df, formula='hospital_mortality ~ cluster + Age + Sex')
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     hospital_mortality   No. Observations:                  466
# Model:                            GLM   Df Residuals:                      460
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -218.68
# Date:                Sat, 08 Mar 2025   Deviance:                       437.37
# Time:                        12:30:14   Pearson chi2:                     458.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.07567
# Covariance Type:                  HC0
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.4548      0.638     -5.411      0.000      -4.706      -2.203
# cluster[T.3]     0.2550      0.455      0.561      0.575      -0.636       1.146
# cluster[T.4]     0.6226      0.458      1.361      0.174      -0.274       1.519
# cluster[T.5]    -0.1777      0.455     -0.390      0.696      -1.070       0.714
# Sex[T.Male]     -0.2091      0.276     -0.757      0.449      -0.750       0.332
# Age              0.0386      0.008      4.973      0.000       0.023       0.054
# ================================================================================
#
# Odds Ratios:
# Intercept       0.031595
# cluster[T.3]    1.290432
# cluster[T.4]    1.863798
# cluster[T.5]    0.837172
# Sex[T.Male]     0.811340
# Age             1.039401
# dtype: float64
#
# P-values:
# Intercept       6.260393e-08
# cluster[T.3]    5.748472e-01
# cluster[T.4]    1.735705e-01
# cluster[T.5]    6.961821e-01
# Sex[T.Male]     4.488934e-01
# Age             6.592064e-07
# dtype: float64

# %% [markdown]
# ## 6. Correlation with Pathogen

# %%
#correlation_columns = list(col for col in df_raw.columns if col.startswith('primary'))
correlation_columns = ["subject_id", "primary_organism_colony_count_b1_datetime"]
df_pathogen_correlation = pd.merge(df_raw[correlation_columns], df_biomarker, on='subject_id', how='inner')
# df_pathogen_correlation.drop(columns=["Unnamed: 0"], inplace=True)
df_pathogen_correlation
# Out:
#     subject_id  primary_organism_colony_count_b1_datetime  cluster
# 0         3901                                        NaN        3
# 1         3695                                    12000.0        4
# 2         4097                                    15000.0        4
# 3         3738                                    10000.0        3
# 4         3791                                        NaN        4
# ..         ...                                        ...      ...
# 461       3564                                        NaN        1
# 462       3884                                    30000.0        1
# 463       4057                                     5000.0        3
# 464       3682                                        NaN        1
# 465       3765                                        NaN        1
#
# [466 rows x 3 columns]

# %%
df_pathogen_correlation["primary_organism_colony_count_b1_datetime"].corr(df_pathogen_correlation["cluster"], method='spearman')
# Out:
# np.float64(-0.01347387262802718)
